# %%
import numpy as np
import matplotlib.pyplot as plt
RR = [8,16,64,100,128,150,200,300]
data0 = np.loadtxt('sensor_0.00/sensor_150x225.data')

# %%
data = np.loadtxt(f'sensor_0.03/sensor_150x225.data')

# %%
a=1
tt=0.75
plt.plot(data0[int(240*a):int(240*(a+tt)),0],-data0[int(240*a):int(240*(a+tt)),1] + data[int(240*a):int(240*(a+tt)),1])

# %%
dt = data0[1,0] - data0[0,0]

# %%
rate = 1/dt
rate
# Out:
# 239.9998080001536

# %%
DD=[]
rr =np.arange(2,13)/100 # np.sort(np.append(np.append(np.arange(7)*0.002+0.005,np.arange(1,13)/100),0.035+np.arange(6)*0.002))
for r in rr:
    data = np.loadtxt(f'sensor_{r:02.02f}/sensor_150x225.data')
    diff = max(abs(-data0[int(240*a):int(240*(a+tt)),1] + data[int(240*a):int(240*(a+tt)),1]))
    DD.append(diff)
plt.xlim(0,0.13)
plt.ylim(0,0.08)
plt.xlabel('R')
plt.ylabel("Амплитуда отраженной волны")
plt.scatter(rr,DD)
plt.savefig('refl_amp.pdf')

# %%
plt.xlabel('1/R')
plt.ylabel("Амплитуда отраженной волны")
plt.plot(RR,DD)
plt.savefig('refl_amp_inv.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 plt.xlabel('1/R')
#       2 plt.ylabel("Амплитуда отраженной волны")
# ----> 3 plt.plot(RR,DD)
#       4 plt.savefig('refl_amp_inv.pdf')
#
# File /usr/lib/python3.11/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
# ...

# %%
np.sort(np.append(np.arange(6)*0.002+0.005,np.arange(1,13)/100))

# %%
DD
